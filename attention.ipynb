# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## seaborn

# %%
import seaborn as sns
# Out:
# /home/ahmedalanasweh/data-visualization/.venv/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
sns.set() # set default plotter to be seaborn

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset("attention")

# %%
data.head(10)
# Out:
#    Unnamed: 0  subject attention  solutions  score
# 0           0        1   divided          1    2.0
# 1           1        2   divided          1    3.0
# 2           2        3   divided          1    3.0
# 3           3        4   divided          1    5.0
# 4           4        5   divided          1    4.0
# 5           5        6   divided          1    5.0
# 6           6        7   divided          1    5.0
# 7           7        8   divided          1    5.0
# 8           8        9   divided          1    2.0
# 9           9       10   divided          1    6.0

# %% [markdown]
# ##  visauliztion data subject vs score

# %%
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
# fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="subject", y="score", hue="solutions",data=data)
# Out:
# <AxesSubplot:xlabel='subject', ylabel='score'>

# %% [markdown]
# ##  visauliztion data subject vs score only

# %%
sns.lineplot(x="subject", y="score", data=data)
# Out:
# <AxesSubplot:xlabel='subject', ylabel='score'>

# %%
sns.lineplot(x="subject", y="solutions", data=data)
# Out:
# <AxesSubplot:xlabel='subject', ylabel='solutions'>

# %%
sns.lineplot(x="subject", y="score",hue="attention", data=data)
# Out:
# <AxesSubplot:xlabel='subject', ylabel='score'>

# %% [markdown]
# ### the max score at 12.5 subject
# ### the solution wthi  score is constant
# ### mi score is 2 at 8  subject
