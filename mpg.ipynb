# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## seaborn

# %%
import seaborn as sns
# Out:
# /home/ahmedalanasweh/data-visualization/.venv/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
sns.set() # set default plotter to be seaborn

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset("mpg")

# %%
data.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# ...

# %%
data_groubedmax = data.groupby("mpg").max()

# %%
data_groubedmean= data.groupby("mpg").mean()

# %%
data_groubedmax
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model_year  \
# mpg
# 9.0           8         304.0       193.0    4732          18.5          70
# 10.0          8         360.0       215.0    4615          15.0          70
# 11.0          8         429.0       210.0    4997          14.0          73
# 12.0          8         455.0       225.0    4955          13.5          73
# 13.0          8         440.0       215.0    5140          16.0          76
# ...         ...           ...         ...     ...           ...         ...
# 43.4          4          90.0        48.0    2335          23.7          80
# 44.0          4          97.0        52.0    2130          24.6          82
# 44.3          4          90.0        48.0    2085          21.7          80
# 44.6          4          91.0        67.0    1850          13.8          80
# 46.6          4          86.0        65.0    2110          17.9          80
#
#       origin                      name
# mpg
# ...

# %%
data_groubedmean
# Out:
#       cylinders  displacement  horsepower   weight  acceleration  model_year
# mpg
# 9.0         8.0        304.00      193.00  4732.00     18.500000        70.0
# 10.0        8.0        333.50      207.50  4495.50     14.500000        70.0
# 11.0        8.0        374.25      187.00  4419.00     12.375000        72.0
# 12.0        8.0        394.50      185.00  4786.50     12.083333        72.5
# 13.0        8.0        353.00      158.35  4254.45     12.935000        73.3
# ...         ...           ...         ...      ...           ...         ...
# 43.4        4.0         90.00       48.00  2335.00     23.700000        80.0
# 44.0        4.0         97.00       52.00  2130.00     24.600000        82.0
# 44.3        4.0         90.00       48.00  2085.00     21.700000        80.0
# 44.6        4.0         91.00       67.00  1850.00     13.800000        80.0
# 46.6        4.0         86.00       65.00  2110.00     17.900000        80.0
#
# [129 rows x 6 columns]

# %% [markdown]
# ## vizulization  between acceleration horsepower displacement,weight

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

rs = np.random.RandomState(365)
values = rs.randn(365, 4).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365 )
data = pd.DataFrame(values, dates, columns=["acceleration", "horsepower", "displacement", "weight"])
data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %%
sns.set_theme(style="whitegrid")

rs = np.random.RandomState(365)
values = rs.randn(365, 4).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365 )
data = pd.DataFrame(values, dates, columns=["acceleration", "horsepower", "mpg", "weight"])
data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %%
sns.set_theme(style="whitegrid")

rs = np.random.RandomState(365)
values = rs.randn(365, 4).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365 )
data = pd.DataFrame(values, dates, columns=["acceleration", "horsepower", "mpg", "weight"])
data = data.rolling(7).mean()

sns.lineplot(data=data_groubedmean, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
sns.set_theme(style="whitegrid")

rs = np.random.RandomState(365)
values = rs.randn(365, 4).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365 )
data = pd.DataFrame(values, dates, columns=["acceleration", "horsepower", "mpg", "weight"])
data = data.rolling(7).mean()

sns.lineplot(data=data_groubedmax, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='mpg'>

# %% [markdown]
# ### reverse relationship between mpg vs wehight
# ### The values between the data are close to each other
